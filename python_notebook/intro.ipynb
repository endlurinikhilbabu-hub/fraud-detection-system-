# %% [markdown]
# # Welcome to your Python notebook
#
# This notebook was created for your project.

# %%
print('Hello from Jupyter!')
x = 10
y = 20
print(x + y)
# Out:
# Hello from Jupyter!
# 30

# %%
def display():
    x=10
    print(x)
display()
# Out:
# 10

# %%
T =10
while T>0:
    print(T)
    if T%2 ==0:
        print(f"{T} is Even Number")
        
        
    T -= 1
# Out:
# 10
# 10 is Even Number
# 9
# 8
# 8 is Even Number
# 7
# 6
# 6 is Even Number
# 5
# 4
# 4 is Even Number
# 3
# 2
# 2 is Even Number
# 1

# %%
x = 8

if x > 5:
    print("A")

if x > 10:
    print("B")
else:
    print("C")
# Out:
# A
# C

# %%
age=20
if age>=18:
    print("Eligible")
else:
    print("Not")
# Out:
# Eligible

# %%
age = 20

if age >= 18:
    print("Eligible")
else:
    print("Not eligible")
# Out:
#   Cell In[4], line 3
#     if age >= 18
#                 ^
# SyntaxError: expected ':'

# %%
i=1
while(i<=5):
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
n = int(input("Enter the number: "))
if n < 0 or n > 100:
    print("Invalid")
elif n >= 90 and n <= 100:
    print("Excellent")
elif n > 75 and n < 90:
    print("Good")
elif n >= 50 and n <= 75:
    print("Pass")
else:
    print("Fail")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 n=int(input("ENter the number"))
#       2 if n<=0 or n>=100:
#       3     print("Invalid")
#       4 elif n>=90 or n<=100:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
# ...

# %%
import numpy as np
a= np.array([1,10,20,30,40,50]).reshape([2,3])
print(a)
# Out:
# [[ 1 10 20]
#  [30 40 50]]

# %%
arr=np.array([5,12,8,21,3,17])
a= arr[arr>10]
print(a)
# Out:
# [12 21 17]

# %%
a=np.array([[1,2,3],[4,5,6],[8,9,0]])
b=np.array([1,0,1])
c=a+b
print(c)
# Out:
# [[2 2 4]
#  [5 5 7]
#  [9 9 1]]

# %%
import numpy as np
def array(arr):
    mean = np.mean(arr)
    std=np.std(arr)
    if std ==0 :
        return np.zeros(arr)
    return (arr-mean)/std
